# %% [markdown]
# # Setup YOLO11
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.5/112.6 GB disk)

# %% [markdown]
# # 1. Predict ( Test Setup YOLO11)
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/bus.jpg'

# %% [markdown]
# # 2. Add Zip Data Export YOLO11 for Roboflow

# %%
import zipfile
from google.colab import files

# %cd /content
uploaded = files.upload()
for filename in uploaded.keys():
  pass

zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall("/content/")
# Out:
# /content
#      <input type="file" id="files-ac1f3577-3b02-4670-9168-46696c6dece2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac1f3577-3b02-4670-9168-46696c6dece2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# # 3. Train Data Roboflow

# %%
# Validate YOLOv8n
# !yolo train model=yolo11n.pt data=data.yaml epochs=200 imgsz=640
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 4. Test Model Training

# %%
# !yolo detect predict model=/content/runs/detect/train2/weights/best.pt conf=0.8 imgsz=640 source='/content/test/images/'
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/3 /content/test/images/yt-qCY8_SQ93O8-0004_jpg.rf.597ab7a0cc9efb8e49d4f1dad2d9fdc7.jpg: 640x640 2 1s, 1 5, 11.9ms
# image 2/3 /content/test/images/yt-qCY8_SQ93O8-0013_jpg.rf.afbe7ad9ac554fdb4052dfb33e1ea3af.jpg: 640x640 1 1, 2 10s, 2 5s, 12.1ms
# image 3/3 /content/test/images/yt-qCY8_SQ93O8-0019_jpg.rf.397616f66a4c88f163998063c8085a56.jpg: 640x640 1 1, 2 10s, 9.4ms
# Speed: 2.5ms preprocess, 11.2ms inference, 52.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 5. Test Video for Model Ai

# %%
# !yolo detect predict model=/content/runs/detect/train2/weights/best.pt  conf=0.55 imgsz=640 source='/content/Dataset (YOLO11) 1080.mp4'
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 72.0ms
# video 1/1 (frame 2/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 13.0ms
# video 1/1 (frame 3/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 11.1ms
# video 1/1 (frame 4/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 10.8ms
# video 1/1 (frame 5/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 11.3ms
# video 1/1 (frame 6/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 11.2ms
# video 1/1 (frame 7/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 11.0ms
# video 1/1 (frame 8/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 10.8ms
# video 1/1 (frame 9/2614) /content/Dataset (YOLO11) 1080.mp4: 640x384 1 1, 10.8ms
# ...
